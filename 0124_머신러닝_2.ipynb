# %% [markdown]
# <a href="https://colab.research.google.com/github/eileen-2/orm/blob/main/0124_%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 머신러닝
# ## 1. 모델비교
#   1.1 앙상블 모델 - 랜덤포레스트 활용하기(알고리즘)
#   1.2

# %%
# 와인 퀄리티 예상해보기 - 랜덤포레스트

# %%
## 기본 패키지 모음
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

## 전처리 및 모델링 준비를 위한 패키지
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split

## 실제 모델링을 위한 패키지
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn import tree
from sklearn.ensemble import RandomForestClassifier


## 모델 평가를 위한 패키지
from sklearn.metrics import classification_report
from sklearn import metrics

# %%
# 1. data import
# 다운 받은 데이터 불러오기
wine = pd.read_csv('/content/winequality_red.csv')
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        5
# 1         9.8        5
# 2         9.8        5
# 3         9.8        6
# 4         9.4        5
# ...       ...      ...
# 1594     10.5        5
# 1595     11.2        6
# 1596     11.0        6
# 1597     10.2        5
# 1598     11.0        6
#
# [1599 rows x 12 columns]

# %%
wine.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
wine.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# 타겟:우리가 예측해야하는 변수 / 분류해야하는 변수
wine['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
# 2. data check
wine.describe()
wine.isnull().sum()
wine['quality'].unique()
sns.countplot(x='quality', data=wine)

# 특성별도 데이터를 시각화 하여 데이터에 대한 정보를 파악합니다
df1 = wine.select_dtypes([int, float])

for i, col in enumerate(df1.columns):
    plt.figure(i)
    sns.barplot(x='quality', y =col, data=df1)

# %%
# 특성별도 데이터를 시각화 하여 데이터에 대한 정보를 파악합니다
df1 = wine.select_dtypes([int, float])

for i, col in enumerate(df1.columns):
    plt.figure(i)
    sns.barplot(x='quality', y =col, data=df1)

    #분포나 경향이 비슷하면 변수로 쓰기에는 적절하지 않구나!
    # 차이가 두드러지는 변수로 설정해서 봐야함

# %%
# 분류 : 좋으나 나쁘냐 중 택 1
# 회귀 : 집값 연속적인 값 0~1억 - > 이중 얼마?
# 회귀를 분류로 변경할 수 있다.
# 회귀 -> 분류 0월 5천만원 -> 집값이 낮다 / 5천~1억 - 분류

# %%
## 6.5점을 기준으로 좋은 와인과 나쁜 와인을 구분하겠다고 선언
bins = (2, 6.5, 8)
group_names = ['bad', 'good']
wine['quality'] = pd.cut(wine['quality'], bins = bins, labels = group_names)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-2a84de303ae2> in <cell line: 4>()
#       2 bins = (2, 6.5, 8)
#       3 group_names = ['bad', 'good']
# ----> 4 wine['quality'] = pd.cut(wine['quality'], bins = bins, labels = group_names)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/tile.py in cut(x, bins, right, labels, retbins, precision, include_lowest, duplicates, ordered)
#     291             raise ValueError("bins must increase monotonically.")
#     292
# --> 293     fac, bins = _bins_to_cuts(
#     294         x,
#     295         bins,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/tile.py in _bins_to_cuts(x, bins, right, labels, precision, include_lowest, dtype, duplicates, ordered)
#     426
#     427     side: Literal["left", "right"] = "left" if right else "right"
# --> 428     ids = ensure_platform_int(bins.searchsorted(x, side=side))
#     429
#     430     if include_lowest:
#
# TypeError: '<' not supported between instances of 'float' and 'str'

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol quality
# 0         9.4     bad
# 1         9.8     bad
# 2         9.8     bad
# 3         9.8     bad
# 4         9.4     bad
# ...       ...     ...
# 1594     10.5     bad
# 1595     11.2     bad
# 1596     11.0     bad
# 1597     10.2     bad
# 1598     11.0     bad
#
# [1599 rows x 12 columns]

# %%
## Good/Bad는 인식할 수 없음. 따라서 컴퓨터가 이를 인식할 수 있도록 Label Encoding을 실시

label_quality = LabelEncoder()
wine['quality'] = label_quality.fit_transform(wine['quality'])

# %%
wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 0         9.4        0
# 1         9.8        0
# 2         9.8        0
# 3         9.8        0
# 4         9.4        0
# ...       ...      ...
# 1594     10.5        0
# 1595     11.2        0
# 1596     11.0        0
# 1597     10.2        0
# 1598     11.0        0
#
# [1599 rows x 12 columns]

# %%
##종속변수와 독립변수를 나누어주는 작업
x = wine.drop('quality', axis = 1)
y = wine['quality']

## 변수별로 Train과 Test 쓸 데이터 셋을 분류x
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)


## 측정 지표의 표준화.
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.fit_transform(x_test)

# %%
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                    11.0                  34.0  0.99780  3.51       0.56
# 1                    25.0                  67.0  0.99680  3.20       0.68
# 2                    15.0                  54.0  0.99700  3.26       0.65
# 3                    17.0                  60.0  0.99800  3.16       0.58
# 4                    11.0                  34.0  0.99780  3.51       0.56
# ...                   ...                   ...      ...   ...        ...
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol
# 0         9.4
# 1         9.8
# 2         9.8
# 3         9.8
# 4         9.4
# ...       ...
# 1594     10.5
# 1595     11.2
# 1596     11.0
# 1597     10.2
# 1598     11.0
#
# [1599 rows x 11 columns]

# %%
# 표준화 - 평균에 의거해서 데이터가 정렬(분포 -> 로그화 와 비슷한 느낌)
x_train
# Out:
# array([[ 0.21833164,  0.88971201,  0.19209222, ...,  1.09349989,
#          0.45822284,  1.12317723],
#        [-1.29016623, -1.78878251,  0.65275338, ..., -0.40043872,
#         -0.40119696,  1.40827174],
#        [ 1.49475291, -0.78434707,  1.01104539, ..., -0.07566946,
#          0.51551749, -0.58738978],
#        ...,
#        [-0.65195559,  0.49909822, -1.08752211, ...,  1.28836145,
#         -0.68767023, -0.87248428],
#        [-0.24582155, -1.84458448,  0.39683051, ...,  0.05423824,
#          0.80199076,  1.40827174],
#        [-1.46422367, -1.34236676, -0.06383064, ...,  0.50891521,
#         -0.68767023,  2.92877575]])

# %%
# 여러가지 모델을 한꺼번에 검토하기
# accuracy랑 변수에 대한 각 결과 값(0과 1에 대한 precision recall f1 score support)

# %%
## 로지스틱 회귀
model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print(classification_report(y_test, y_pred))

print("Accuracy:", metrics.accuracy_score(y_test, y_pred))
print("Precision:", metrics.precision_score(y_test, y_pred))
print("Recall:", metrics.recall_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       273
#            1       0.71      0.26      0.37        47
#
#     accuracy                           0.88       320
#    macro avg       0.80      0.62      0.65       320
# weighted avg       0.86      0.88      0.85       320
#
# Accuracy: 0.875
# Precision: 0.7058823529411765
# Recall: 0.2553191489361702

# %%
## SVC
model_svc = SVC()
model_svc.fit(x_train, y_train)
y_pred_svc = model_svc.predict(x_test)
print(classification_report(y_test, y_pred_svc))

print("Accuracy:", metrics.accuracy_score(y_test, y_pred_svc))
print("Precision:", metrics.precision_score(y_test, y_pred_svc))
print("Recall:", metrics.recall_score(y_test, y_pred_svc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93       273
#            1       0.71      0.26      0.37        47
#
#     accuracy                           0.88       320
#    macro avg       0.80      0.62      0.65       320
# weighted avg       0.86      0.88      0.85       320
#
# Accuracy: 0.875
# Precision: 0.7058823529411765
# Recall: 0.2553191489361702

# %%
## KNN
model_knn = KNeighborsClassifier(5)
model_knn.fit(x_train, y_train)
y_pred_knn = model_knn.predict(x_test)
print(classification_report(y_test, y_pred_knn))

print("Accuracy:", metrics.accuracy_score(y_test, y_pred_knn))
print("Precision:", metrics.precision_score(y_test, y_pred_knn))
print("Recall:", metrics.recall_score(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       273
#            1       0.61      0.40      0.49        47
#
#     accuracy                           0.88       320
#    macro avg       0.76      0.68      0.71       320
# weighted avg       0.86      0.88      0.86       320
#
# Accuracy: 0.875
# Precision: 0.6129032258064516
# Recall: 0.40425531914893614

# %%
## NB
model_NB = GaussianNB()
model_NB.fit(x_train, y_train)
y_pred_NB = model_NB.predict(x_test)
print(classification_report(y_test, y_pred_NB))

print("Accuracy:", metrics.accuracy_score(y_test, y_pred_NB))
print("Precision:", metrics.precision_score(y_test, y_pred_NB))
print("Recall:", metrics.recall_score(y_test, y_pred_NB))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91       273
#            1       0.50      0.74      0.60        47
#
#     accuracy                           0.85       320
#    macro avg       0.73      0.81      0.75       320
# weighted avg       0.89      0.85      0.86       320
#
# Accuracy: 0.853125
# Precision: 0.5
# Recall: 0.7446808510638298

# %%
## Decision Tree
model_tree = tree.DecisionTreeClassifier()
model_tree.fit(x_train, y_train)
y_pred_tree = model_tree.predict(x_test)
print(classification_report(y_test, y_pred_tree))

print("Accuracy:", metrics.accuracy_score(y_test, y_pred_tree))
print("Precision:", metrics.precision_score(y_test, y_pred_tree))
print("Recall:", metrics.recall_score(y_test, y_pred_tree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.92      0.91       273
#            1       0.48      0.45      0.46        47
#
#     accuracy                           0.85       320
#    macro avg       0.69      0.68      0.69       320
# weighted avg       0.84      0.85      0.84       320
#
# Accuracy: 0.846875
# Precision: 0.4772727272727273
# Recall: 0.44680851063829785

# %%
## RandomForest
model_rfc = RandomForestClassifier(n_estimators=200)
model_rfc.fit(x_train, y_train)
y_pred_rfc = model_rfc.predict(x_test)
print(classification_report(y_test, y_pred_rfc))

print("Accuracy:", metrics.accuracy_score(y_test, y_pred_rfc))
print("Precision:", metrics.precision_score(y_test, y_pred_rfc))
print("Recall:", metrics.recall_score(y_test, y_pred_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.96      0.93       273
#            1       0.64      0.38      0.48        47
#
#     accuracy                           0.88       320
#    macro avg       0.77      0.67      0.71       320
# weighted avg       0.86      0.88      0.86       320
#
# Accuracy: 0.878125
# Precision: 0.6428571428571429
# Recall: 0.3829787234042553

# %%
print("Logistic Regression Accuracy:", metrics.accuracy_score(y_test, y_pred))
print("Support Vector Machine Accuracy:", metrics.accuracy_score(y_test, y_pred_svc))
print("KNN Accuracy:", metrics.accuracy_score(y_test, y_pred_knn))
print("Gausian NB Accuracy:", metrics.accuracy_score(y_test, y_pred_NB))
print("Decision Tree Accuracy:", metrics.accuracy_score(y_test, y_pred_NB))
print("Random Forest Accuracy:", metrics.accuracy_score(y_test, y_pred_rfc))

acc_df = pd.DataFrame({'classifier':
                      ['Logistic Regression ',
                       'Support Vector Machine',
                       'KNN',
                       'Gausian NB',
                       'Decision Tree',
                       'Random Forest'],
                      'accuracy':
                      [metrics.accuracy_score(y_test, y_pred),
                       metrics.accuracy_score(y_test, y_pred_svc),
                       metrics.accuracy_score(y_test, y_pred_knn),
                       metrics.accuracy_score(y_test, y_pred_NB),
                       metrics.accuracy_score(y_test, y_pred_tree),
                       metrics.accuracy_score(y_test, y_pred_rfc),
                       ]
                      })

acc_df
# Out:
# Logistic Regression Accuracy: 0.875
# Support Vector Machine Accuracy: 0.875
# KNN Accuracy: 0.875
# Gausian NB Accuracy: 0.853125
# Decision Tree Accuracy: 0.853125
# Random Forest Accuracy: 0.878125
#                classifier  accuracy
# 0    Logistic Regression   0.875000
# 1  Support Vector Machine  0.875000
# 2                     KNN  0.875000
# 3              Gausian NB  0.853125
# 4           Decision Tree  0.846875
# 5           Random Forest  0.878125

# %% [markdown]
# #1.2 트리모델
# - 분류 모델을 사용할 때 더 적합
#
#  ** 결정 트리 ; 마치 if-else가 산재한 느

# %%
# 결정트리 ; 많은 데이터일수록, 데이터라벨이 잘 되어 있을 수
 #- 규칙노드 ; 어떤 규칙의 조건
 #- 리프노드 ; 결정된 분류값
 #- 서브노드 ; 곁가지

# %%
##종속변수와 독립변수를 나누어주는 작업
x = wine.drop('quality', axis = 1)
y = wine['quality']

## 변수별로 Train과 Test 쓸 데이터 셋을 분류x
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state = 2023)
dt.fit(x_train, y_train)
print(dt.score(x_train, y_train))
print(dt.score(x_test, y_test))
# Out:
# 1.0
# 0.9

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
plt.figure(figsize =(10,7))
plot_tree(dt)
plt.show()

# %% [markdown]
# # 중요~

# %%
# 맨위 분류 1번
# 조건 알코올 11.55도 이
# sample 1279개 - 품질 나쁜음료 (6.5이하) 1109개 / 품 좋은 음료 (6.5이상)170개

# %%
plt.figure(figsize =(10,7))
plot_tree(dt, max_depth = 1, filled = True) #max_depth 가 1
plt.show()

# %%
# 조건
# 불순도(gini)
# 총 샘플 수 = 1279개
# 클래스별 샘플(value) value = [1109, 170] 1109개


# 지니계수가 0에 가까울 수록 좋은 케이스

# %%
# 검증
'''
1. 직접적인 데이터 검증
2. 성능 비교 ; 과적합 나지 않았는지 / 성능이 너무 낮지 않은지 확인

# %% [markdown]
# 3. 랜덤 포레스트
# <특징>
# **데이터**
# 1. 데이터를 랜덤하게 추출해서 훈련데이터를 만든다
# 2. 데이터를 재추출하여 훈련데이터를 만든다->(다양한 경우의 수로 학습가능) => "부스트랩"Boostrap
# 3. 중복 추출로 train datset과 돋일하게 추출
#
# ** 변수**
# -변수도 랜덤 추출
#
#
# 그런데 왜 중복추출해서 주머니(트리)를 나누냐?
# >> 짱1명을 일반학생 100명이 이길 수 있다.
# => 앙상블 학습(보팅/배깅/부스팅)
#
# # 앙상블 학습
# ## 1. 보팅; 여러 친구들의 의견을 모아서 결정(가중치-> 주관적..?)
# ## 2. 배깅 ; 각자 다른 전략으로 플레이하고 결과를 모두 합친 후 결정(각각의 장단점을 다 가져가자)
# ## 3. 부스팅; 오답노트 풀어서 고쳐 나가는 것
# ## 4. 스테킹: 각자 풀고 그중 최고를 가리는
